# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('supermarkets.xlsx')

# %%
df
# Out:
#     Invoice ID Branch       City Customer  Gender Product lin  Unit price  \
# 0    750-67-84      A     Yangon   Member  Female  Health and       74.69
# 1    226-31-30      C  Naypyitaw   Normal  Female  Electronic       15.28
# 2    631-41-31      A     Yangon   Normal    Male    Home and       46.33
# 3    123-19-11      A     Yangon   Member    Male  Health and       58.22
# 4    373-73-79      A     Yangon      NaN    Male  Sports and       86.31
# ..         ...    ...        ...      ...     ...         ...         ...
# 995  233-67-57      C  Naypyitaw   Normal    Male  Health and       40.35
# 996  303-96-22      B   Mandalay   Normal  Female    Home and       97.38
# 997  727-02-13      A     Yangon   Member    Male  Food and b       31.84
# 998  347-56-24      A     Yangon   Normal    Male    Home and       65.82
# 999  849-09-38      A        NaN   Member  Female  Fashion ac       88.34
#
#      Quantity   Tax 5%      Total                 Date   Time      Payment  \
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID     0
# Branch         2
# City           2
# Customer       5
# Gender         1
# Product lin    5
# Unit price     6
# Quantity       4
# Tax 5%         1
# Total          7
# Date           3
# Time           1
# Payment        7
# cogs           1
# gross marg     5
# gross inco     1
# Rating         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Invoice ID   1000 non-null   object
#  1   Branch       998 non-null    object
#  2   City         998 non-null    object
#  3   Customer     995 non-null    object
#  4   Gender       999 non-null    object
#  5   Product lin  995 non-null    object
#  6   Unit price   994 non-null    float64
#  7   Quantity     996 non-null    float64
#  8   Tax 5%       999 non-null    float64
#  9   Total        993 non-null    float64
#  10  Date         997 non-null    object
#  11  Time         999 non-null    object
#  12  Payment      993 non-null    object
#  13  cogs         999 non-null    float64
#  14  gross marg   995 non-null    float64
#  15  gross inco   999 non-null    float64
#  16  Rating       998 non-null    float64
# dtypes: float64(8), object(9)
# memory usage: 132.9+ KB

# %%
df.shape
# Out:
# (949, 18)

# %%
#Dropping all the nan values as ratio of nan value is very less
df.dropna(axis=0,inplace=True)

# %%
df['Time'] =pd.to_datetime(df['Time'], format = '%H:%M')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 949 entries, 0 to 998
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Invoice ID   949 non-null    object
#  1   Branch       949 non-null    object
#  2   City         949 non-null    object
#  3   Customer     949 non-null    object
#  4   Gender       949 non-null    object
#  5   Product lin  949 non-null    object
#  6   Unit price   949 non-null    float64
#  7   Quantity     949 non-null    float64
#  8   Tax 5%       949 non-null    float64
#  9   Total        949 non-null    float64
#  10  Date         949 non-null    object
#  11  Time         949 non-null    datetime64[ns]
#  12  Payment      949 non-null    object
#  13  cogs         949 non-null    float64
#  14  gross marg   949 non-null    float64
#  15  gross inco   949 non-null    float64
#  16  Rating       949 non-null    float64
# dtypes: datetime64[ns](1), float64(8), object(8)
# ...

# %%
df.describe()
# Out:
#        Unit price    Quantity      Tax 5%        Total        cogs  \
# count  949.000000  949.000000  949.000000   949.000000  949.000000
# mean    55.582055    5.487882   15.292389   321.140165  305.847777
# std     26.439731    2.932991   11.682345   245.329247  233.646902
# min     10.080000    1.000000    0.508500    10.678500   10.170000
# 25%     32.900000    3.000000    5.832000   122.472000  116.640000
# 50%     54.920000    5.000000   12.036000   252.756000  240.720000
# 75%     77.720000    8.000000   22.428000   470.988000  448.560000
# max     99.960000   10.000000   49.650000  1042.650000  993.000000
#
#          gross marg  gross inco      Rating
# count  9.490000e+02  949.000000  949.000000
# mean   4.761905e+00   15.292389    6.981454
# std    8.886467e-16   11.682345    1.723918
# min    4.761905e+00    0.508500    4.000000
# 25%    4.761905e+00    5.832000    5.500000
# 50%    4.761905e+00   12.036000    7.000000
# 75%    4.761905e+00   22.428000    8.500000
# ...

# %%
df.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer',
#  'Gender',
#  'Product lin',
#  'Date',
#  'Payment']

# %%
df[['Branch','City','Customer','Gender','Product lin','Date','Payment']].describe()
# Out:
#        Branch    City Customer Gender Product lin      Date Payment
# count     949     949      949    949         949       949     949
# unique      3       3        2      2           6        54       3
# top         A  Yangon   Member   Male  Fashion ac  ########    Cash
# freq      322     322      480    475         172       392     330

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 949 entries, 0 to 998
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Invoice ID   949 non-null    object
#  1   Branch       949 non-null    object
#  2   City         949 non-null    object
#  3   Customer     949 non-null    object
#  4   Gender       949 non-null    object
#  5   Product lin  949 non-null    object
#  6   Unit price   949 non-null    float64
#  7   Quantity     949 non-null    float64
#  8   Tax 5%       949 non-null    float64
#  9   Total        949 non-null    float64
#  10  Date         949 non-null    object
#  11  Time         949 non-null    object
#  12  Payment      949 non-null    object
#  13  cogs         949 non-null    float64
#  14  gross marg   949 non-null    float64
#  15  gross inco   949 non-null    float64
#  16  Rating       949 non-null    float64
# dtypes: float64(8), object(9)
# memory usage: 133.5+ KB

# %%
df["Hour"] = df['Time'].dt.hour

# %%
df
# Out:
#     Invoice ID Branch       City Customer  Gender Product lin  Unit price  \
# 0    750-67-84      A     Yangon   Member  Female  Health and       74.69
# 1    226-31-30      C  Naypyitaw   Normal  Female  Electronic       15.28
# 2    631-41-31      A     Yangon   Normal    Male    Home and       46.33
# 3    123-19-11      A     Yangon   Member    Male  Health and       58.22
# 5    699-14-30      C  Naypyitaw   Normal    Male  Electronic       85.39
# ..         ...    ...        ...      ...     ...         ...         ...
# 993  690-01-66      B   Mandalay   Normal    Male  Fashion ac       17.49
# 994  652-49-67      C  Naypyitaw   Member  Female  Electronic       60.95
# 995  233-67-57      C  Naypyitaw   Normal    Male  Health and       40.35
# 997  727-02-13      A     Yangon   Member    Male  Food and b       31.84
# 998  347-56-24      A     Yangon   Normal    Male    Home and       65.82
#
#      Quantity   Tax 5%     Total                 Date                Time  \
# ...

# %%
df['Product lin'].value_counts()
# Out:
# Fashion ac    172
# Food and b    165
# Sports and    162
# Electronic    160
# Home and      148
# Health and    142
# Name: Product lin, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Yangon       322
# Mandalay     314
# Naypyitaw    313
# Name: City, dtype: int64

# %% [markdown]
# ## EDA

# %%
sns.set_theme()
sns.countplot(x = 'Branch', data = df, palette = "magma")
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
sns.countplot(x = 'Branch',hue='City', data = df, palette = "magma")
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %% [markdown]
# ### From the insights we find that the number of branches are almost equal, and each branch corresponds to one city

# %%
sns.barplot(x = 'Branch',y='Total', data = df, palette = "magma", hue='Gender')
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %%
sns.barplot(x = 'City',y='Total', data = df, palette = "magma", hue='Branch')
# Out:
# <AxesSubplot:xlabel='City', ylabel='Total'>

# %% [markdown]
# ### As we can see from above 2 plots that there's a noticeable difference in Sales as Branch C which also belongs to Naypyitaw City does the highest sales. But still the sales is almost similar in all branches.

# %%
sns.barplot(x='Gender',y='gross inco', data=df, hue='Branch')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross inco'>

# %%
sns.barplot(x='Gender',y='Quantity', data=df,hue='Branch')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Quantity'>

# %%
sns.barplot(x='City',y='Rating', data=df, hue='Gender')
# Out:
# <AxesSubplot:xlabel='City', ylabel='Rating'>

# %% [markdown]
# ### The rating given is also similar among Male and Females across different city and branch

# %%
sns.countplot(x = 'Payment', data = df, palette = 'magma')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
sns.countplot(x = 'Payment', data = df, palette = 'magma',hue='City')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %% [markdown]
# ### Payment mode of Credit card is slightly less used than other 2 modes.

# %%
sns.countplot(x = 'Product lin', data = df, palette = 'magma',hue='Gender')
# Out:
# <AxesSubplot:xlabel='Product lin', ylabel='count'>

# %% [markdown]
# ### The highest buying product by females is Fashion and least bought is Health products, whereas there's no significant difference in buying of males.

# %%
sns.countplot(hue = 'Product lin', data = df, palette = 'magma',x='City')
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
sns.catplot(x='Rating', y= 'cogs', data=df)

# %%
sns.lineplot(data=df, x="Hour", y="gross inco")
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='gross inco'>

# %% [markdown]
# ### Sales is highest at 14 hour i.e 2pm

# %%
sns.scatterplot(x="Rating",y='gross inco',data=df)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='gross inco'>

# %%
plt.figure(figsize = (12,10))

sns.heatmap(df.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(20,14))
plt.show()

# %% [markdown]
# ### Majority of customers Total lies between 10-200, so as gross income and cogs.
# ### The majority of the products has the unit price of 25 or 95.
# ### Ratings given by customers is almost similar whereas majority of ratings received are of 4.5 and 9.6.

# %%
sns.pairplot(df)

# %% [markdown]
# # Model Building

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer', 'Gender', 'Product lin',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross marg', 'gross inco', 'Rating'],
#       dtype='object')

# %%
X = df[['cogs','Rating']]
y = df['gross inco']

# %%
X
# Out:
#        cogs  Rating
# 0    522.83     9.1
# 1     76.40     9.6
# 2    324.31     7.4
# 3    465.76     8.4
# 5    597.73     4.1
# ..      ...     ...
# 993  174.90     6.6
# 994   60.95     5.9
# 995   40.35     6.2
# 997   31.84     7.7
# 998   65.82     4.1
#
# [949 rows x 2 columns]

# %%
y
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 5      29.8865
#         ...
# 993     8.7450
# 994     3.0475
# 995     2.0175
# 997     1.5920
# 998     3.2910
# Name: gross inco, Length: 949, dtype: float64

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,random_state=0,test_size=0.2)

# %% [markdown]
# ## Linear Regression Model

# %% [markdown]
# ### As Linear Regression works on distance matrix to fit a Best fit line. We need to scale our X data before giving to the model.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

scaler = StandardScaler().fit(x_train)
rescaled_X_train = scaler.transform(x_train)
model = LinearRegression()
model.fit(rescaled_X_train, y_train)

# transform the validation dataset
rescaled_X_test = scaler.transform(x_test)
predictions = model.predict(rescaled_X_test)


print (f"MSE: {mean_squared_error(y_test, predictions)}")
print (f"RMSE: {sqrt(mean_squared_error(y_test, predictions))}")
# Out:
# MSE: 5.46164214817704e-29
# RMSE: 7.390292381345301e-15

# %%
mse=cross_val_score(model,rescaled_X_train,y_train,scoring='neg_mean_squared_error',cv=5)
mean_mse=np.mean(mse)
print(mse)
print(mean_mse)
# Out:
# [-5.82044411e-30 -8.55765684e-29 -7.28025847e-30 -5.97151811e-30
#  -7.80257228e-30]
# -2.249027227751026e-29

# %% [markdown]
# ### Comparing the predicted and actual value

# %%
compare = pd.DataFrame({'Prediction': predictions, 'Test Data' : y_test})
compare.head(10)
# Out:
#      Prediction  Test Data
# 915     10.6470    10.6470
# 599      7.0320     7.0320
# 272      9.6930     9.6930
# 356     18.7750    18.7750
# 520      6.8565     6.8565
# 729     18.2630    18.2630
# 862      5.0760     5.0760
# 762     25.5520    25.5520
# 17      21.7830    21.7830
# 38      21.9680    21.9680

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(x_train, y_train)
predictions = model.predict(x_test)

print (f"MSE: {mean_squared_error(y_test, predictions)}")
print (f"RMSE: {sqrt(mean_squared_error(y_test, predictions))}")
# Out:
# MSE: 0.009595282894736797
# RMSE: 0.09795551487658465

# %%
compare = pd.DataFrame({'Prediction': predictions, 'Test Data' : y_test})
compare.head(10)
# Out:
#      Prediction  Test Data
# 915     10.6225    10.6470
# 599      7.0380     7.0320
# 272      9.6750     9.6930
# 356     18.7775    18.7750
# 520      6.8200     6.8565
# 729     18.2745    18.2630
# 862      5.0950     5.0760
# 762     25.5640    25.5520
# 17      21.7800    21.7830
# 38      22.0100    21.9680

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(x_train, y_train)
predictions = model.predict(x_test)


print (f"MSE: {mean_squared_error(y_test, predictions)}")
print (f"RMSE: {sqrt(mean_squared_error(y_test, predictions))}")
# Out:
# MSE: 0.003053991242631348
# RMSE: 0.055262928284984573

# %%
compare = pd.DataFrame({'Prediction': predictions, 'Test Data' : y_test})
compare.head(10)
# Out:
#      Prediction  Test Data
# 915   10.651005    10.6470
# 599    7.029150     7.0320
# 272    9.682440     9.6930
# 356   18.798120    18.7750
# 520    6.856150     6.8565
# 729   18.308240    18.2630
# 862    5.103420     5.0760
# 762   25.518875    25.5520
# 17    21.786980    21.7830
# 38    22.021985    21.9680
